# %%
#Q 1.  How is an image formed?

An image is formed because light emanates from an object in a variety of directionsImage Actually formed by
Discrete number of pixels.The light then hits an array of sensors inside the camera. Each sensor produces electric
charges that are read by an electronic circuit and converted to voltages. These are in turn sampled by a device 
called a digitizer (or analog-to-digital converter) to produce the numbers that computers eventually process, 
called pixel values. Thus, the pixel values are a rather indirect encoding of the physical properties of visible 
surfaces.
Their values depend on the image types:
 . colour 
 . Grayscale.

# %%
#Q 2. Difference between human vision and machine vision.

Human vision factually uses the combination of Brain, Eyes, ear along with some sort of senses they have.
First off, the objectives of the two systems are the same: to convert light into useful signals from which
to construct accurate models of the physical world. Similarly, when considered at an important level, the 
structures of human and computer vision are similar: both have light sensors which convert photons into a 
signal, a transfer mechanism to carry the signal, and an “understanding place” where the signal is interpreted.
    
In Real life you can see high resolution images. On the other hand, machines can also detect high resolution 
images but have lost some information.But yes, there are some differences between these two systems which we can 
differentiate from each other.Computer vision allows computers to sense Their surroundings and identify things, 
like how human vision perceives things. On the other hand, human vision Humans perceive things as they are and 
retain what they recognize, storing it deep in the brain until they come across those things again.Computer Vision
Uses Machine Learning techniques and algorithms to identify, distinguish and classify objects but Human vision is 
about how eyes detect light patterns and coordinate with the brain to translate light into images.Objectrecognition
is one of the most challenging problems in computer vision. In contrast Humans recognize objects effortlessly and
have no problems describing objects in a scene.

# %%
#3. Enumerate major fields in computer vision, and explain them.

There are three major field of computer vision 
.Image processing 
.Image Analysis
.Machine vision 
.Object Detection
.Event Detection
.Video tracking
.3D pose Estimation
.3D scan Modeling 
 
 
Image processing contains those following operation 
1. Image
2. Pixel operations
3. Neighborhood operations
4. Geometric operations

A method for modifying an image to produce a better image or to extract some relevant information from it is known
as "image processing." It is a kind of signal processing where the input is an image and the output can either 
be another image or traits or features related to that image.

Image Analysis also consist some of the steps :
Image Acquisition
Image Enhencement
Image compression
 
objective: reduce irrelevant and redundant image data in order to be able to store or transmit data in an efficient
form.
 
Image Restoration
- Improving the appearance of an image Colour Image Processing
-Use the colour of the image to extract features of interest in an image
Image Segmentation
-Segmentation procedures partition an image into its constituent parts or objects.
machine vision
Cameras are used by machine vision to collect visual data from the environment. It then prepares the data
for usage in various applications by processing the photos using a combination of hardware and software.
Specialized optics are frequently used in machine vision technology to capture images. With this method, 
specific image properties can be processed, examined, and assessed. 

For instance, a manufacturing system may employ a machine vision application to examine a specific feature of a 
component that is being produced on an assembly line. If the component doesn't satisfy the required standards, it
could be discarded.
# Out:
#   Input In [85]
#     There are three major field of computer vision
#           ^
# SyntaxError: invalid syntax

# %%
#4 Write a function (in MATLAB/Python) that can access gray level intensity value of the studied 
#image I of any location,I(i, j).

import numpy as np
import cv2
import imageio
from matplotlib import pyplot as plt
img = cv2.imread("zarin_khan.jpeg")
# print(img)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# print(gray)

# %%
plt.imshow(img)

# %%
# plt.imshow(img)
plt.imshow(gray,cmap='gray')
plt.show()

# %%
#Q 5


arith_op = input('''INPUT OPERATION:
                sum, substract, multiply, divide''')

def arithmetic_operations(A,B,arith_op):
    if arith_op=="sum":
        operation=sum
        
    elif arith_op=="substract":
        operation=sub
    
    elif arith_op=="mul":
        mul(A,B)
    else:
        div(A,B)
        
    for i in range(size):
        for j in range(size):
            print(size)
            c[i][j]=operation(A[i][j],B[i][j])
    print(c)
    
def sub(a,b):
    return a + b
def sub(a,b):
    return a-b
def sub(a,b):
    return a - b

def mul(A,B):
    if A.shape[-1] != B.shape[0]:
        print("cannot multiply: the column of first matrix doesn't match with the row of")
    else:
        B=transpose(b)
def transpose(mat):
    for i in range(size):
        for j in range(size):
            mat[i][j]=mat[j][i]




def plus(num1,num2):
    print(num1+num2)
    return

def minus(num1,num2):
    print(num1-num2)
    return

num1=int(input("First Value: "))
num2=int(input("Second value: "))

choise=input(
"""
Select your function:
a. Add
b. subtract
c. multiply
d. divide
""")

if choice=="a":
    print("The answer is: ", end="")
    plus(num1,num2)
elif choice=="b":
    print("The answer is: ", end="")
    minus(num1,num2)


# In[ ]:
5
# Out:
# INPUT OPERATION:
#                 sum, substract, multiply, divide2,3
# First Value: 4

# %%
# Q 6
import numpy as np
import cv2
#import imageio
from matplotlib import pyplot as plt
img = cv2.imread("zarin_khan.jpeg")
# print(img)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap="gray", vmin=0, vmax=255)

# %%
l=np.array([20,20,20])
h=np.array([2550,250,250])
# B=cv2.inRange(img,l,h)
B,_= cv2.threshold(gray,127,255,type=cv2.THRESH_BINARY)
plt.imshow(_,'gray')
